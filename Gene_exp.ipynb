# %% [markdown]
# <a href="https://colab.research.google.com/github/amrutha1810/BIS-LAB/blob/main/Gene_exp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import numpy as np
import operator


FUNCTIONS = {'+': operator.add, '-': operator.sub, '*': operator.mul, '/': operator.truediv}
TERMINALS = ['x', 1, 2, 3, 4]

def random_gene(length=10):

    return [random.choice(list(FUNCTIONS.keys()) + TERMINALS) for _ in range(length)]


def decode_chromosome(chromosome, x):

    stack = []
    for gene in chromosome:
        if gene in FUNCTIONS:
            if len(stack) < 2:
                stack.append(0)
                continue
            b = stack.pop()
            a = stack.pop()
            try:
                result = FUNCTIONS[gene](a, b)
            except ZeroDivisionError:
                result = 1
            stack.append(result)
        elif gene == 'x':
            stack.append(x)
        else:
            stack.append(gene)
    return stack[0] if stack else 0


def fitness_function(chromosome, target_function, x_values):
    """Calculate fitness based on Mean Squared Error."""
    predictions = [decode_chromosome(chromosome, x) for x in x_values]
    targets = [target_function(x) for x in x_values]
    mse = np.mean([(p - t) ** 2 for p, t in zip(predictions, targets)])
    return mse


def selection(population, fitnesses):

    total_fitness = sum(1 / (f + 1e-6) for f in fitnesses)
    probabilities = [(1 / (f + 1e-6)) / total_fitness for f in fitnesses]
    return population[np.random.choice(len(population), p=probabilities)]


def mutate(chromosome, mutation_rate=0.1):

    new_chromosome = chromosome[:]
    for i in range(len(new_chromosome)):
        if random.random() < mutation_rate:
            new_chromosome[i] = random.choice(list(FUNCTIONS.keys()) + TERMINALS)
    return new_chromosome


def crossover(parent1, parent2):

    point = random.randint(1, len(parent1) - 1)
    child1 = parent1[:point] + parent2[point:]
    child2 = parent2[:point] + parent1[point:]
    return child1, child2


def gene_expression_algorithm(target_function, x_values, population_size=10, generations=20):


    population = [random_gene() for _ in range(population_size)]

    print("Initial Population:")
    for i, chrom in enumerate(population):
        print(f"Chromosome {i}: {chrom}")

    for generation in range(generations):
        print(f"\nGeneration {generation + 1}:")

        fitnesses = [fitness_function(chrom, target_function, x_values) for chrom in population]
        for i, (chrom, fit) in enumerate(zip(population, fitnesses)):
            print(f"Chromosome {i}: {chrom}, Fitness: {fit:.4f}")


        new_population = []
        for _ in range(population_size // 2):
            parent1 = selection(population, fitnesses)
            parent2 = selection(population, fitnesses)
            child1, child2 = crossover(parent1, parent2)
            child1 = mutate(child1)
            child2 = mutate(child2)
            new_population.extend([child1, child2])
        population = new_population


    print("\nFinal Population and Fitness:")
    fitnesses = [fitness_function(chrom, target_function, x_values) for chrom in population]
    for i, (chrom, fit) in enumerate(zip(population, fitnesses)):
        print(f"Chromosome {i}: {chrom}, Fitness: {fit:.4f}")

    best_index = np.argmin(fitnesses)
    print("\nBest Solution:")
    print(f"Chromosome: {population[best_index]}, Fitness: {fitnesses[best_index]:.4f}")


def target_function(x):
    return x**2 + 2*x + 1


x_values = np.linspace(-10, 10, 20)


gene_expression_algorithm(target_function, x_values, population_size=10, generations=10)
# Out:
# Initial Population:
# Chromosome 0: ['*', '/', '*', '*', 3, '*', 4, 'x', 4, 2]
# Chromosome 1: [3, 4, '-', 'x', '*', '+', '/', 4, '*', '/']
# Chromosome 2: [3, '-', 4, '/', '-', '-', '-', 2, 1, 2]
# Chromosome 3: [4, 2, 4, '*', 4, '-', '*', '*', 2, 1]
# Chromosome 4: [3, 1, 2, '*', 'x', 4, 4, '-', '+', '+']
# Chromosome 5: ['*', '+', '+', 'x', 1, 1, '-', 3, 'x', 3]
# Chromosome 6: [2, '-', 1, 4, '/', '-', 'x', '-', '/', 2]
# Chromosome 7: [2, '*', 3, 3, 'x', '-', 3, 2, '*', 'x']
# Chromosome 8: ['-', 1, '+', 'x', 1, 2, 2, 1, '+', '-']
# Chromosome 9: ['*', 2, 4, 1, 1, 2, 3, 1, 2, 'x']
#
# Generation 1:
# Chromosome 0: ['*', '/', '*', '*', 3, '*', 4, 'x', 4, 2], Fitness: 2657.1015
# Chromosome 1: [3, 4, '-', 'x', '*', '+', '/', 4, '*', '/'], Fitness: inf
# Chromosome 2: [3, '-', 4, '/', '-', '-', '-', 2, 1, 2], Fitness: 2439.0488
# Chromosome 3: [4, 2, 4, '*', 4, '-', '*', '*', 2, 1], Fitness: 1702.1541
# Chromosome 4: [3, 1, 2, '*', 'x', 4, 4, '-', '+', '+'], Fitness: 2439.0488
# Chromosome 5: ['*', '+', '+', 'x', 1, 1, '-', 3, 'x', 3], Fitness: 2657.1015
# Chromosome 6: [2, '-', 1, 4, '/', '-', 'x', '-', '/', 2], Fitness: 2667.0638
# Chromosome 7: [2, '*', 3, 3, 'x', '-', 3, 2, '*', 'x'], Fitness: 2509.7331
# Chromosome 8: ['-', 1, '+', 'x', 1, 2, 2, 1, '+', '-'], Fitness: 2582.4173
# Chromosome 9: ['*', 2, 4, 1, 1, 2, 3, 1, 2, 'x'], Fitness: 2657.1015
#
# Generation 2:
# Chromosome 0: [3, 1, '+', 'x', 1, 2, 2, 1, '+', '-'], Fitness: 2370.3646
# Chromosome 1: ['-', '-', 4, '/', '-', '-', '-', 2, 1, 2], Fitness: 2657.1015
# Chromosome 2: [4, 2, 4, '*', 4, '-', '*', 'x', 2, 1], Fitness: 1702.1541
# Chromosome 3: [4, 2, 4, '*', 4, '-', '*', 4, 2, 1], Fitness: 1702.1541
# Chromosome 4: [2, '-', 1, 4, '/', '-', 'x', 2, 1, 2], Fitness: 2509.7331
# Chromosome 5: ['/', '-', 4, '/', '-', '-', '-', '+', '/', 2], Fitness: 2582.4173
# Chromosome 6: [3, '-', 4, '/', 1, 2, 2, 1, '*', '-'], Fitness: 2439.0488
# Chromosome 7: ['-', 1, '+', 'x', '-', 2, '-', 2, 1, 2], Fitness: 2917.9962
# Chromosome 8: ['x', 1, 2, '*', 'x', 4, 4, '-', '+', '+'], Fitness: 2546.5752
# Chromosome 9: [3, 1, 2, 2, 'x', 4, 4, '-', '+', '+'], Fitness: 2439.0488
#
# Generation 3:
# Chromosome 0: [4, 2, 4, '-', 4, '-', '*', 'x', 2, 2], Fitness: 5049.5225
# Chromosome 1: ['-', '-', 4, '/', '-', '*', '-', 2, 1, 1], Fitness: 2657.1015
# Chromosome 2: ['+', '-', 4, '/', 1, 2, 2, 2, 1, 4], Fitness: 2657.1015
# Chromosome 3: [2, '-', 1, 4, '/', '-', 'x', 1, '*', '-'], Fitness: 2509.7331
# Chromosome 4: ['-', 1, '+', 'x', '-', 2, '-', 2, 1, 2], Fitness: 2917.9962
# Chromosome 5: ['-', 1, '+', 'x', '-', '+', '-', 2, 1, 2], Fitness: 2766.6278
# Chromosome 6: [4, 1, '+', 'x', 1, 2, 2, 1, '/', '-'], Fitness: 2303.6804
# Chromosome 7: [3, 2, 4, '*', 4, '-', '*', 'x', 2, 1], Fitness: 1892.8909
# Chromosome 8: [3, '-', '+', 'x', 1, 2, 2, 1, '+', 1], Fitness: 2439.0488
# Chromosome 9: [3, 1, '+', 'x', 1, 2, 2, 1, '+', '-'], Fitness: 2370.3646
#
# Generation 4:
# Chromosome 0: ['-', '-', 4, '/', '-', '*', '-', 2, 1, 1], Fitness: 2657.1015
# Chromosome 1: ['-', '-', 4, '/', '-', '*', '-', 'x', 1, 1], Fitness: 2657.1015
# Chromosome 2: [3, 1, '+', 'x', 1, 2, 2, 2, '*', 2], Fitness: 2370.3646
# Chromosome 3: ['-', 1, '+', 'x', '-', 2, '-', '-', '+', '-'], Fitness: 2917.9962
# Chromosome 4: ['-', '-', 4, '/', '-', '*', '-', 2, 1, '-'], Fitness: 2657.1015
# Chromosome 5: ['+', '-', 1, 4, '/', '-', 'x', 1, '*', 2], Fitness: 2657.1015
# Chromosome 6: [2, '-', 1, 4, 2, '-', 'x', 1, '+', 'x'], Fitness: 2509.7331
# Chromosome 7: [3, '-', '*', 'x', 1, 2, 2, 1, '*', '-'], Fitness: 2657.1015
# Chromosome 8: ['-', '-', 4, 'x', '-', '*', '-', 2, 1, 1], Fitness: 2657.1015
# Chromosome 9: ['-', '-', 4, '/', '-', '*', '-', 2, 'x', 1], Fitness: 2657.1015
#
# Generation 5:
# Chromosome 0: ['-', 1, 2, 'x', '-', 2, '-', 'x', 1, 1], Fitness: 2657.1015
# Chromosome 1: ['-', '-', 4, '/', '-', '*', '-', '-', '+', '-'], Fitness: 2657.1015
# Chromosome 2: ['+', '-', 1, 4, '/', 1, 'x', 2, 1, 1], Fitness: 2657.1015
# Chromosome 3: [1, '-', 4, '/', '-', '*', '-', 1, '*', 2], Fitness: 2582.4173
# Chromosome 4: ['-', '-', 4, '/', '-', '*', '-', 2, 3, 1], Fitness: 2657.1015
# Chromosome 5: ['-', '-', 4, '/', '-', '*', '-', 2, 'x', 1], Fitness: 2657.1015
# Chromosome 6: [3, 1, '+', 'x', 1, 2, 2, 2, 'x', '-'], Fitness: 2370.3646
# Chromosome 7: ['x', '-', 4, '/', 1, '*', '-', 2, 3, 2], Fitness: 2546.5752
# Chromosome 8: [3, '-', '*', '/', '-', '/', '-', 2, 1, 'x'], Fitness: 2657.1015
# Chromosome 9: [2, '-', 1, 4, 2, '-', 'x', 1, '+', 1], Fitness: 2509.7331
#
# Generation 6:
# Chromosome 0: ['-', '-', 4, '-', '-', '*', '-', 2, 'x', 1], Fitness: 2370.3646
# Chromosome 1: ['-', '-', 4, '/', '-', '*', '-', 2, 3, 1], Fitness: 2657.1015
# Chromosome 2: ['-', '-', 4, 'x', '-', 2, '-', 'x', 1, 1], Fitness: 2657.1015
# Chromosome 3: ['-', 1, 2, '/', '-', '*', '-', 2, 3, 1], Fitness: 2695.1936
# Chromosome 4: ['-', '-', 4, '/', '-', '*', '-', '-', '*', '+'], Fitness: 2657.1015
# Chromosome 5: [3, 1, '+', 'x', 1, 2, 2, 2, '+', '-'], Fitness: 2370.3646
# Chromosome 6: [1, '-', 4, '/', '-', '*', '-', 2, 'x', '-'], Fitness: 2582.4173
# Chromosome 7: [3, 1, '+', 'x', 1, '-', 2, 1, '*', 2], Fitness: 2370.3646
# Chromosome 8: [1, '-', 4, 4, 2, '-', 'x', 1, '+', 1], Fitness: 2582.4173
# Chromosome 9: [2, '-', 1, '/', '-', '*', '-', 'x', '*', 2], Fitness: 2509.7331
#
# Generation 7:
# Chromosome 0: [3, 1, '+', 'x', 1, '-', 2, 1, '*', 1], Fitness: 2370.3646
# Chromosome 1: ['-', '-', 4, 2, '-', '*', '-', 2, 3, '+'], Fitness: 2657.1015
# Chromosome 2: ['-', '-', 1, '/', '-', '*', '-', 'x', '*', 2], Fitness: 2657.1015
# Chromosome 3: [2, '-', 4, '-', '-', '*', '-', 2, 'x', 1], Fitness: 2238.9962
# Chromosome 4: [1, 'x', 4, '/', '-', 1, '-', 2, 3, 1], Fitness: 2696.2462
# Chromosome 5: ['-', 1, 2, '/', '-', '*', '-', 2, 'x', '-'], Fitness: 2695.1936
# Chromosome 6: [3, 1, '+', 'x', 'x', 2, 2, 2, 3, 1], Fitness: 2370.3646
# Chromosome 7: ['-', 1, 2, '/', '-', '*', '-', 2, '+', '-'], Fitness: 2545.8252
# Chromosome 8: [2, '+', 1, '/', 4, '*', '-', 1, '+', 1], Fitness: 2439.0488
# Chromosome 9: [1, '-', 4, 4, 2, '-', 'x', 'x', '*', '*'], Fitness: 2582.4173
#
# Generation 8:
# Chromosome 0: [3, 1, '+', 'x', 1, '-', 2, 1, '*', 1], Fitness: 2370.3646
# Chromosome 1: [3, '-', 4, '-', '-', '*', '-', 2, 3, 1], Fitness: 2176.3120
# Chromosome 2: [1, '-', 2, 4, 2, '-', '-', 2, 'x', 1], Fitness: 2582.4173
# Chromosome 3: [2, 4, 4, '-', '-', '+', 'x', 'x', '*', '*'], Fitness: 2509.7331
# Chromosome 4: [3, 1, 2, '/', '-', '*', '-', 2, 4, '-'], Fitness: 2474.1409
# Chromosome 5: ['-', 1, 2, '/', '-', '*', 'x', 2, 'x', '-'], Fitness: 2695.1936
# Chromosome 6: [3, 1, '+', 'x', 'x', 2, 2, 1, '*', 1], Fitness: 2370.3646
# Chromosome 7: [3, 1, '+', 'x', 1, '-', 2, 2, 3, 1], Fitness: 2370.3646
# Chromosome 8: [1, '-', 1, '/', '-', 1, 2, '/', 'x', '-'], Fitness: 2582.4173
# Chromosome 9: ['-', 'x', 4, 4, 2, '-', 'x', 'x', '*', '*'], Fitness: 2657.1015
#
# Generation 9:
# Chromosome 0: [3, '-', 4, 4, 2, '-', 'x', 'x', '*', '/'], Fitness: 2439.0488
# Chromosome 1: ['-', '*', 4, '*', 'x', '*', '/', 2, 3, 1], Fitness: nan
# Chromosome 2: [3, 1, '+', 'x', 1, '-', 2, 2, 3, 1], Fitness: 2370.3646
# Chromosome 3: ['*', 1, '+', 'x', 'x', 2, 4, 1, '*', 1], Fitness: 2582.4173
# Chromosome 4: ['-', 1, '-', '/', '-', '*', 'x', 2, 3, 1], Fitness: 2733.7857
# Chromosome 5: [3, '-', 4, '-', '-', '*', '-', 2, 3, '-'], Fitness: 2176.3120
# Chromosome 6: [2, 4, 4, '-', 2, '-', 'x', 'x', '*', '*'], Fitness: 2509.7331
# Chromosome 7: ['-', 'x', 4, 4, 3, '+', 'x', 'x', '*', '*'], Fitness: 2657.1015
# Chromosome 8: ['-', 1, '*', 4, 2, '-', 'x', 'x', '*', '*'], Fitness: 2657.1015
# Chromosome 9: ['-', 1, 'x', '/', '-', '*', 'x', '-', 'x', '-'], Fitness: 2661.5378
# <ipython-input-1-44320aa64d65>:25: RuntimeWarning: divide by zero encountered in scalar divide
#   result = FUNCTIONS[gene](a, b)
# <ipython-input-1-44320aa64d65>:25: RuntimeWarning: invalid value encountered in scalar divide
#   result = FUNCTIONS[gene](a, b)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-44320aa64d65> in <cell line: 113>()
#     111
#     112
# --> 113 gene_expression_algorithm(target_function, x_values, population_size=10, generations=10)
#     114
#
# <ipython-input-1-44320aa64d65> in gene_expression_algorithm(target_function, x_values, population_size, generations)
#      85         new_population = []
#      86         for _ in range(population_size // 2):
# ---> 87             parent1 = selection(population, fitnesses)
#      88             parent2 = selection(population, fitnesses)
#      89             child1, child2 = crossover(parent1, parent2)
#
# <ipython-input-1-44320aa64d65> in selection(population, fitnesses)
#      46     total_fitness = sum(1 / (f + 1e-6) for f in fitnesses)
#      47     probabilities = [(1 / (f + 1e-6)) / total_fitness for f in fitnesses]
# ---> 48     return population[np.random.choice(len(population), p=probabilities)]
#      49
#      50
#
# numpy/random/mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: probabilities contain NaN
